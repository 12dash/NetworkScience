# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from pyvis.network import Network
import os

# %%
df = pd.read_csv("SCSENodes.csv")
df = df.drop([df.columns[0]], axis = 1)

# %%
for year in range(2000,2022):
    df[str(year)] = df[str(year)].apply(lambda x : x.strip('][').split(','))

# %%
def  init():
    try:
        os.mkdir("Graph")
    except Exception as e:
        pass

# %%
def draw_graph_year(year):
    init()
    G = nx.Graph()
    for i in faculty:
        if i != '':
            G.add_node(i)
    collabs = df[year].to_list()
    for i in range(len(collabs)):
        for j in collabs[i]:
            if j != '':
                G.add_edge(faculty[i],j)  
    plt.figure(figsize = (24,12))
    nx.draw_random(G, with_labels=True, font_weight='bold')
    plt.show()
    g = Network(height = 1024, width = 1024, notebook = True)
    g.toggle_hide_edges_on_drag(True)
    g.barnes_hut()
    g.from_nx(G)
    g.show(f"Graph/{year}.html")

# %%
faculty = df.Faculty.to_list()

# %%
for i in (range(2000,2001)):
    draw_graph_year(str(i))

# %%
draw_graph_year('2000')

# %%
df
# Out:
#                  Faculty             Position Gender Management  \
# 0         A S Madhukumar  Associate Professor      M          N
# 1          Alexei Sourin  Associate Professor      M          N
# 2   Anupam Chattopadhyay  Associate Professor      M          N
# 3        Anwitaman Datta  Associate Professor      M          N
# 4            Arijit Khan  Assistant Professor      M          N
# ..                   ...                  ...    ...        ...
# 80          Wen Yonggang            Professor      M          N
# 81         Zhang Tianwei  Assistant Professor      M          N
# 82             Boyang Li  Associate Professor      M          N
# 83            Liu Zhiwei  Assistant Professor      M          N
# 84          Luu Anh Tuan  Assistant Professor      M          N
#
#                      Area 2000 2001                2002                2003  \
# 0       Computer Networks   []   []  ['Lau Chiew Tong']  ['Lau Chiew Tong']
# 1       Computer Graphics   []   []                  []                  []
# 2   Computer Architecture   []   []                  []                  []
# 3     Distributed Systems   []   []                  []                  []
# 4         Data Management   []   []                  []                  []
# ..                    ...  ...  ...                 ...                 ...
# 80             Multimedia   []   []                  []                  []
# 81         Cyber Security   []   []                  []                  []
# 82                  AI/ML   []   []                  []                  []
# 83        Computer Vision   []   []                  []                  []
# 84                  AI/ML   []   []                  []                  []
#
#                   2004  ...  \
# 0   ['Lau Chiew Tong']  ...
# 1   ['Seah Hock Soon']  ...
# 2                   []  ...
# 3                   []  ...
# 4                   []  ...
# ..                 ...  ...
# 80                  []  ...
# 81                  []  ...
# 82                  []  ...
# 83                  []  ...
# 84                  []  ...
#
#                                                  2012  \
# 0                                  ['Lau Chiew Tong']
# 1                                  ['Seah Hock Soon']
# 2                                ['Sourav Sen Gupta']
# 3   ['Sun Aixin',  'Lee Bu Sung Francis',  'Zhang ...
# 4                                                  []
# ..                                                ...
# 80                   ['Cai Jianfei',  'Ng Wee Keong']
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                                       ['Liu Yang']
#
#                                                  2013  \
# 0                                  ['Lau Chiew Tong']
# 1                                  ['Seah Hock Soon']
# 2                                ['Sourav Sen Gupta']
# 3   ['Sun Aixin',  'Ng Wee Keong',  'Lee Bu Sung F...
# 4                                                  []
# ..                                                ...
# 80  ['Ong Yew Soon',  'Cai Jianfei',  'Ng Wee Keong']
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                                       ['Liu Yang']
#
#                                                  2014  \
# 0                 ['Dusit Niyato',  'Lau Chiew Tong']
# 1                                  ['Seah Hock Soon']
# 2                                ['Sourav Sen Gupta']
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4                                                  []
# ..                                                ...
# 80  ['Cai Jianfei',  'Dusit Niyato',  'Ng Wee Keon...
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                                       ['Liu Yang']
#
#                                                  2015  \
# 0                 ['Lau Chiew Tong',  'Dusit Niyato']
# 1                                  ['Seah Hock Soon']
# 2                                ['Sourav Sen Gupta']
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4                                                  []
# ..                                                ...
# 80  ['Dusit Niyato',  'Ong Yew Soon',  'Cai Jianfe...
# 81                                                 []
# 82  ['Yu Han',  'Shen Zhiqi',  'Ong Yew Soon',  'M...
# 83                                                 []
# 84                                       ['Liu Yang']
#
#                                                  2016  \
# 0                 ['Dusit Niyato',  'Lau Chiew Tong']
# 1                                  ['Seah Hock Soon']
# 2    ['Thambipillai Srikanthan',  'Sourav Sen Gupta']
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4                                                  []
# ..                                                ...
# 80  ['Lin Weisi',  'Cai Jianfei',  'Ng Wee Keong',...
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                    ['Hui Siu Cheung',  'Liu Yang']
#
#                                                  2017  \
# 0                 ['Lau Chiew Tong',  'Dusit Niyato']
# 1                                  ['Seah Hock Soon']
# 2   ['Erik Cambria',  'Arvind Easwaran',  'Lam Kwo...
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4                               ['Sourav S Bhowmick']
# ..                                                ...
# 80  ['Dusit Niyato',  'Cai Jianfei',  'Miao Chunya...
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                    ['Hui Siu Cheung',  'Liu Yang']
#
#                                                  2018  \
# 0                 ['Lau Chiew Tong',  'Dusit Niyato']
# 1                                  ['Seah Hock Soon']
# 2   ['Lam Kwok Yan',  'Sourav Sen Gupta',  'Arvind...
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4                  ['Cong Gao',  'Sourav S Bhowmick']
# ..                                                ...
# 80  ['Ong Yew Soon',  'Cai Jianfei',  'Yu Han',  '...
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                    ['Hui Siu Cheung',  'Liu Yang']
#
#                                                  2019  \
# 0                 ['Lau Chiew Tong',  'Dusit Niyato']
# 1                                  ['Seah Hock Soon']
# 2   ['Sourav Sen Gupta',  'Owen Noel Newton Fernan...
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4                  ['Sourav S Bhowmick',  'Cong Gao']
# ..                                                ...
# 80  ['Dusit Niyato',  'Tan Rui',  'Cai Jianfei',  ...
# 81                                                 []
# 82  ['Ong Yew Soon',  'Yu Han',  'Shen Zhiqi',  'M...
# 83                                                 []
# 84                    ['Hui Siu Cheung',  'Liu Yang']
#
#                                                  2020  \
# 0                 ['Lau Chiew Tong',  'Dusit Niyato']
# 1                                  ['Seah Hock Soon']
# 2   ['Guan Cuntai',  'Arvind Easwaran',  'Sourav S...
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4   ['Cong Gao',  'Sourav Sen Gupta',  'Sourav S B...
# ..                                                ...
# 80  ['Tan Rui',  'Dusit Niyato',  'Zhang Tianwei',...
# 81                      ['Liu Yang',  'Wen Yonggang']
# 82  ['Miao Chunyan',  'Ong Yew Soon',  'Yu Han',  ...
# 83                                ['Arvind Easwaran']
# 84                    ['Liu Yang',  'Hui Siu Cheung']
#
#                                                  2021
# 0                 ['Lau Chiew Tong',  'Dusit Niyato']
# 1                                  ['Seah Hock Soon']
# 2   ['Sourav Sen Gupta',  'Thambipillai Srikanthan...
# 3   ['Ng Wee Keong',  'Sun Aixin',  'Lee Bu Sung F...
# 4   ['Sourav S Bhowmick',  'Cong Gao',  'Sourav Se...
# ..                                                ...
# 80  ['Cai Jianfei',  'Ng Wee Keong',  'Ong Yew Soo...
# 81                      ['Liu Yang',  'Wen Yonggang']
# 82  ['Yu Han',  'Miao Chunyan',  'Ong Yew Soon',  ...
# 83                                ['Arvind Easwaran']
# 84                    ['Hui Siu Cheung',  'Liu Yang']
#
# [85 rows x 27 columns]

# %%
year = '2000'
G = nx.Graph()
for i in faculty:
    G.add_node(i)
collabs = df[year].to_list()
for i in range(len(collabs)):
    for j in collabs[i]:
        G.add_edge(faculty[i],j)  
plt.figure(figsize = (24,12))
nx.draw_random(G, with_labels=True, font_weight='bold')
plt.show()
g = Network(height = 1024, width = 1024, notebook = True)
g.toggle_hide_edges_on_drag(True)
g.barnes_hut()
g.from_nx(G)
g.show(f"{year}.html")
# Out:
#         <iframe
#             width="1024"
#             height="1024"
#             src="2000.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
